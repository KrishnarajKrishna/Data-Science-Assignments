# %%
import pandas as pd

# %%
# Import Train Dataset
s_train = pd.read_csv('SalaryData_Train.csv')
s_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
# Import Test Dataset
s_test = pd.read_csv('SalaryData_Test.csv')
s_test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
columns_str = ["workclass","education","maritalstatus","occupation","relationship","race","sex","native","Salary"]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in columns_str:
    train[i] = le.fit_transform(train[i])
    test[i] = le.fit_transform(test[i])

# %%
train.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1         2174            0            40      37
# 1             0     4    1            0            0            13      37
# 2             1     4    1            0            0            40      37
# 3             0     2    1            0            0            40      37
# 4             5     2    0            0            0            40       4
#
#    Salary
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
test.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   25          2          1            7              4           6
# 1   38          2         11            9              2           4
# 2   28          1          7           12              2          10
# 3   44          2         15           10              2           6
# 4   34          2          0            6              4           7
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             3     2    1            0            0            40      37
# 1             0     4    1            0            0            50      37
# 2             0     4    1            0            0            40      37
# 3             0     2    1         7688            0            40      37
# 4             1     4    1            0            0            30      37
#
#    Salary
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0

# %%
features = train.iloc[:,:13]
label = train.iloc[:,13]

# %%
#import categorical naive model
from sklearn.naive_bayes import CategoricalNB
model = CategoricalNB()
model.fit(features,label)
# Out:
# CategoricalNB()

# %%
#for test data
from sklearn.metrics import accuracy_score, confusion_matrix
features1 = test.iloc[:,:13]
label1 = test.iloc[:,13]

y_pred = model.predict(features1)
acc = accuracy_score(label1,y_pred)*100
print("accuracy score=",acc)
# Out:
# accuracy score= 85.66401062416999

# %%
confusion_matrix(label1, y_pred)
# Out:
# array([[10475,   885],
#        [ 1274,  2426]], dtype=int64)
