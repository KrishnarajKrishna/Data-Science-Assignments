# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
import numpy as np

from sklearn import preprocessing
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import f1_score

from sklearn.metrics import accuracy_score
from sklearn.ensemble import BaggingClassifier  
from sklearn.ensemble import AdaBoostClassifier 

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

import warnings
warnings.filterwarnings('ignore')

# %%
f_check =  pd.read_csv("Fraud_check.csv")
f_check.head()
# Out:
#   Undergrad Marital.Status  Taxable.Income  City.Population  Work.Experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban
# 0   YES
# 1   YES
# 2   YES
# 3   YES
# 4    NO

# %%
f_check.describe()
# Out:
#        Taxable.Income  City.Population  Work.Experience
# count      600.000000       600.000000       600.000000
# mean     55208.375000    108747.368333        15.558333
# std      26204.827597     49850.075134         8.842147
# min      10003.000000     25779.000000         0.000000
# 25%      32871.500000     66966.750000         8.000000
# 50%      55074.500000    106493.500000        15.000000
# 75%      78611.750000    150114.250000        24.000000
# max      99619.000000    199778.000000        30.000000

# %%
f_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Undergrad        600 non-null    object
#  1   Marital.Status   600 non-null    object
#  2   Taxable.Income   600 non-null    int64
#  3   City.Population  600 non-null    int64
#  4   Work.Experience  600 non-null    int64
#  5   Urban            600 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 28.2+ KB

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
f_check['Undergrad']= label_encoder.fit_transform(f_check['Undergrad'])
f_check['Marital.Status'] =label_encoder.fit_transform(f_check['Marital.Status'])
f_check['Urban'] = label_encoder.fit_transform(f_check['Urban'])

# %%
f_check.head()
# Out:
#    Undergrad  Marital.Status  Taxable.Income  City.Population  \
# 0          0               2           68833            50047
# 1          1               0           33700           134075
# 2          0               1           36925           160205
# 3          1               2           50190           193264
# 4          0               1           81002            27533
#
#    Work.Experience  Urban
# 0               10      1
# 1               18      1
# 2               30      1
# 3               15      1
# 4               28      0

# %%
f_check.dtypes
# Out:
# Undergrad          int32
# Marital.Status     int32
# Taxable.Income     int64
# City.Population    int64
# Work.Experience    int64
# Urban              int32
# dtype: object

# %%
f_check.rename({'Undergrad':'UG','Marital.Status':'MS','Taxable.Income':'TI','City.Population':'CP','Work.Experience':'WE'}, axis =1, inplace= True)
f_check
# Out:
#      UG  MS     TI      CP  WE  Urban
# 0     0   2  68833   50047  10      1
# 1     1   0  33700  134075  18      1
# 2     0   1  36925  160205  30      1
# 3     1   2  50190  193264  15      1
# 4     0   1  81002   27533  28      0
# ..   ..  ..    ...     ...  ..    ...
# 595   1   0  76340   39492   7      1
# 596   1   0  69967   55369   2      1
# 597   0   0  47334  154058   0      1
# 598   1   1  98592  180083  17      0
# 599   0   0  96519  158137  16      0
#
# [600 rows x 6 columns]

# %%
f_check['TI']= f_check.TI.map(lambda taxable_income: 'Risky' if taxable_income <= 30000 else 'Good')
f_check
# Out:
#      UG  MS    TI      CP  WE  Urban
# 0     0   2  Good   50047  10      1
# 1     1   0  Good  134075  18      1
# 2     0   1  Good  160205  30      1
# 3     1   2  Good  193264  15      1
# 4     0   1  Good   27533  28      0
# ..   ..  ..   ...     ...  ..    ...
# 595   1   0  Good   39492   7      1
# 596   1   0  Good   55369   2      1
# 597   0   0  Good  154058   0      1
# 598   1   1  Good  180083  17      0
# 599   0   0  Good  158137  16      0
#
# [600 rows x 6 columns]

# %%
x = f_check.iloc[:,[0,1,3,4,5]]
x
# Out:
#      UG  MS      CP  WE  Urban
# 0     0   2   50047  10      1
# 1     1   0  134075  18      1
# 2     0   1  160205  30      1
# 3     1   2  193264  15      1
# 4     0   1   27533  28      0
# ..   ..  ..     ...  ..    ...
# 595   1   0   39492   7      1
# 596   1   0   55369   2      1
# 597   0   0  154058   0      1
# 598   1   1  180083  17      0
# 599   0   0  158137  16      0
#
# [600 rows x 5 columns]

# %%
y = f_check['TI']
y
# Out:
# 0      Good
# 1      Good
# 2      Good
# 3      Good
# 4      Good
#        ...
# 595    Good
# 596    Good
# 597    Good
# 598    Good
# 599    Good
# Name: TI, Length: 600, dtype: object

# %%
#splitting into train and test data 
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.3, random_state= 10)

# %% [markdown]
# #### 1.Decision tree using entropy method by ---  C5.0

# %%
model_1 = DecisionTreeClassifier(criterion = 'entropy', max_depth = 3,class_weight= 'balanced') # 
model_1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=3)

# %%
# Plot
tree.plot_tree(model_1);

# %%
fn = ['UG','MS','CP','WE','Urban']
cn = ['Taxable_income is Risky', 'Taxable_income is Good']
fig, axes = plt.subplots(nrows=1, ncols=1,figsize =(5,5),dpi= 500 )
tree.plot_tree(model_1,
              feature_names=fn,
              class_names= cn,
              filled= True);

# %%
#predicting on test data
preds_1= model_1.predict(x_test)
preds_1[0:30]
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Risky', 'Good', 'Good', 'Good', 'Risky', 'Good'], dtype=object)

# %%
pd.Series(preds_1).value_counts()
# Out:
# Good     157
# Risky     23
# dtype: int64

# %%
# confusion matrix
pd.crosstab(preds_1,y_test)
# Out:
# TI     Good  Risky
# row_0
# Good    121     36
# Risky    17      6

# %%
#Accuracy
np.mean(preds_1==y_test)*100
# Out:
# 70.55555555555556

# %%
print(classification_report(preds_1, y_test))
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.88      0.77      0.82       157
#        Risky       0.14      0.26      0.18        23
#
#     accuracy                           0.71       180
#    macro avg       0.51      0.52      0.50       180
# weighted avg       0.78      0.71      0.74       180

# %%
print("Accuracy C5:", accuracy_score(y_test,preds_1)*100)
# Out:
# Accuracy C5: 70.55555555555556

# %% [markdown]
# #### 2.Decision Tree using Gini method by --  CART

# %%
model_2 = DecisionTreeClassifier(criterion='gini', max_depth= 3, class_weight= 'balanced')
model_2.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=3)

# %%
tree.plot_tree(model_2);

# %%
# Extraction features- 
fn = ['UG','MS','CP','WE','Urban']
cn = ['Taxable_income is Risky', 'Taxable_income is Good']
fig,axes = plt.subplots(nrows=1, ncols=1, figsize=(4,4),dpi = 500)
tree.plot_tree(model_2,
              feature_names= fn,
              class_names= cn,
              filled = True);

# %%
#predicting on data set
preds_2= model_2.predict(x_test)
preds_2[0:60]
# Out:
# array(['Good', 'Good', 'Risky', 'Good', 'Risky', 'Risky', 'Risky',
#        'Risky', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Risky', 'Risky',
#        'Risky', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Risky', 'Good',
#        'Good', 'Risky', 'Good', 'Good', 'Good', 'Risky', 'Risky', 'Risky',
#        'Risky', 'Risky', 'Good', 'Risky', 'Good', 'Risky', 'Risky',
#        'Good', 'Good', 'Good', 'Risky', 'Risky', 'Good', 'Risky', 'Good',
#        'Good', 'Risky', 'Risky', 'Good', 'Risky', 'Risky', 'Good',
#        'Risky', 'Risky', 'Risky', 'Risky', 'Good', 'Good', 'Good'],
#       dtype=object)

# %%
pd.Series(preds_2).value_counts()
# Out:
# Risky    91
# Good     89
# dtype: int64

# %%
np.mean(preds_2==y_test)
# Out:
# 0.46111111111111114

# %%
print("Accuracy CART: ", accuracy_score(y_test,preds_2)*100)
# Out:
# Accuracy CART:  46.111111111111114

# %% [markdown]
# #### 3.Model by -- Bagging

# %%
dcmodel_3= BaggingClassifier(DecisionTreeClassifier(max_depth= 6), random_state=7)

# %%
# Train decision tree
dcmodel_3 = dcmodel_3.fit(x_train,y_train) 
y_preds_3 = dcmodel_3.predict(x_test)

# %%
y_preds_3[0:20]
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Risky',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good'], dtype=object)

# %%
np.mean(y_preds_3 == y_test)*100
# Out:
# 76.11111111111111

# %%
print("Accuracy by Bagging Classifier : ", np.round((accuracy_score(y_test,y_preds_3)*100),2))
# Out:
# Accuracy by Bagging Classifier :  76.11

# %%
print(confusion_matrix(y_test,y_preds_3))
print(classification_report(y_test,y_preds_3))
# Out:
# [[135   3]
#  [ 40   2]]
#               precision    recall  f1-score   support
#
#         Good       0.77      0.98      0.86       138
#        Risky       0.40      0.05      0.09        42
#
#     accuracy                           0.76       180
#    macro avg       0.59      0.51      0.47       180
# weighted avg       0.68      0.76      0.68       180

# %% [markdown]
# #### 4. Model by -- Boosting

# %%
dcmodel_4 = AdaBoostClassifier(DecisionTreeClassifier(max_depth= 6),random_state=7)

# %%
dcmodel_4 = dcmodel_4.fit(x_train,y_train) 
y_preds_4 = dcmodel_4.predict(x_test)

# %%
y_preds_4 [0:50]
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Risky', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good'], dtype=object)

# %%
np.mean(y_preds_4==y_test)*100
# Out:
# 72.22222222222221

# %%
print("Accuracy by AdaBoost Classifier : ", accuracy_score(y_test,y_preds_4)*100 )
# Out:
# Accuracy by AdaBoost Classifier :  72.22222222222221

# %%
print(confusion_matrix(y_test,y_preds_4))
print(classification_report(y_test,y_preds_4))
# Out:
# [[125  13]
#  [ 37   5]]
#               precision    recall  f1-score   support
#
#         Good       0.77      0.91      0.83       138
#        Risky       0.28      0.12      0.17        42
#
#     accuracy                           0.72       180
#    macro avg       0.52      0.51      0.50       180
# weighted avg       0.66      0.72      0.68       180

# %%
#### 5. Model using --  Random Forest

# %%
rf = RandomForestClassifier(n_jobs = 3,oob_score = True,n_estimators = 15,criterion ="entropy")

# %%
num_trees= 100
max_features= 3
kfold= KFold(n_splits=10)

# %%
model_5 = RandomForestClassifier(n_estimators= num_trees, max_features= max_features)
model_5.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_features=3)

# %%
results = cross_val_score(model_5, x, y, cv= kfold)
results
# Out:
# array([0.78333333, 0.75      , 0.66666667, 0.68333333, 0.75      ,
#        0.63333333, 0.83333333, 0.7       , 0.73333333, 0.85      ])

# %%
print(results.mean())
# Out:
# 0.7383333333333333

# %%
y_preds_5 = model_5.predict(x_test)
y_preds_5 [0:40]
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Risky',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good'],
#       dtype=object)

# %%
crosstable = pd.crosstab(y_test, y_preds_5)
crosstable
# Out:
# col_0  Good  Risky
# TI
# Good    128     10
# Risky    40      2

# %%
# Comparing the predicted values with the actual values and calculating mean for the matches
np.mean(y_preds_5 ==y_test)
# Out:
# 0.7222222222222222

# %%
print(classification_report(y_preds_5, y_test))
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.93      0.76      0.84       168
#        Risky       0.05      0.17      0.07        12
#
#     accuracy                           0.72       180
#    macro avg       0.49      0.46      0.46       180
# weighted avg       0.87      0.72      0.79       180

# %%
rf.fit(x_train,y_train)
print("no of estimators: ",rf.estimators_) 
print("no of class labels: ",rf.classes_)    
print("no of class labels: ",rf.n_classes_)    
print("no of features : ",rf.n_features_)    
print("no of outputs : ",rf.n_outputs_)  
print("out of bag score : ",np.round(rf.oob_score_*100))
# Out:
# no of estimators:  [DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=596277691), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=2632409), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=1786445681), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=1817988101), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=504291336), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=1536456329), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=755222340), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=558417586), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=703292453), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=1156855178), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=612983032), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=691320598), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=55892164), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=298686366), DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=446939412)]
# no of class labels:  ['Good' 'Risky']
# no of class labels:  2
# no of features :  5
# no of outputs :  1
# out of bag score :  73.0

# %%
rf.predict(x_test) [0:50]
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good'], dtype=object)

# %%
y_preds_5 =rf.predict(x_test)
pd.Series(y_preds_5).value_counts()
# Out:
# Good     162
# Risky     18
# dtype: int64

# %%
y_preds_5 [0:40]
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good'],
#       dtype=object)

# %%
crosstable = pd.crosstab(y_test,y_preds_5)
crosstable
# Out:
# col_0  Good  Risky
# TI
# Good    122     16
# Risky    40      2

# %%
print(classification_report(y_preds_5, y_test))
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.88      0.75      0.81       162
#        Risky       0.05      0.11      0.07        18
#
#     accuracy                           0.69       180
#    macro avg       0.47      0.43      0.44       180
# weighted avg       0.80      0.69      0.74       180

# %% [markdown]
# #### Comparison of all models:

# %%
print("Accuracy by C5: ",np.round(accuracy_score(y_test,preds_1)*100))
print("Accuracy by CART: ",np.round(accuracy_score(y_test,preds_2)*100))
print("Accuracy by Bagging Classifier : ",np.round(accuracy_score(y_test,y_preds_3)*100))
print("Accuracy by Adaboost : ",np.round(accuracy_score(y_test,y_preds_4)*100))
print("Accuracy by Random Forest : ", np.round(accuracy_score(y_test,y_preds_5)*100))
# Out:
# Accuracy by C5:  71.0
# Accuracy by CART:  46.0
# Accuracy by Bagging Classifier :  76.0
# Accuracy by Adaboost :  72.0
# Accuracy by Random Forest :  69.0
